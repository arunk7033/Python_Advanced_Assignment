# %% [markdown]
# ## Assignment_9

# %%
Q1. In Python 3.X, what are the names and functions of string object types?

# %%
#Solution:
In Python 3.x, strings are represented by the str class, and there are several built-in string methods that can be applied to string objects. Here are some common string methods along with their functions:
1. str.capitalize(): Returns a copy of the string with its first character capitalized and the rest lowercased.
s = "hello world"
result = s.capitalize()  # "Hello world"
2. str.upper(): Returns a copy of the string with all characters in uppercase.
s = "hello world"
result = s.upper()  # "HELLO WORLD"
3. str.lower(): Returns a copy of the string with all characters in lowercase.
s = "HELLO WORLD"
result = s.lower()  # "hello world"
4. str.title(): Returns a copy of the string with the first character of each word capitalized.
s = "hello world"
result = s.title()  # "Hello World"
5. str.strip(): Returns a copy of the string with leading and trailing whitespaces removed.
s = "   hello world   "
result = s.strip()  # "hello world"
6. str.replace(old, new): Returns a copy of the string with occurrences of the specified substring replaced with another substring.
s = "hello world"
result = s.replace("world", "Python")  # "hello Python"
7. str.startswith(prefix) and str.endswith(suffix): Return True if the string starts with (ends with) the specified prefix (suffix), otherwise return False.
s = "hello world"
starts_with_hello = s.startswith("hello")  # True
ends_with_world = s.endswith("world")  # True

# %%
Q2. How do the string forms in Python 3.X vary in terms of operations?

# %%
#Solution:
In Python 3.x, strings are immutable, meaning their values cannot be changed after creation. This immutability affects the way string operations are performed. Here are some key characteristics and variations in string operations in Python 3.x:
1. Immutability:
- Strings are immutable, meaning we cannot modify the contents of an existing string. Instead, operations on strings create new strings.
2. Concatenation:
The + operator is used for string concatenation. It creates a new string that is a concatenation of the two original strings.
s1 = "Hello"
s2 = "World"
result = s1 + " " + s2  # "Hello World"
3. Repetition:
- The * operator can be used to repeat a string.
s = "abc"
result = s * 3  # "abcabcabc"
4. Indexing and Slicing:
- Strings support indexing and slicing operations. Indexing returns a single character, and slicing returns a substring.
s = "Python"
char = s[0]  # 'P'
substring = s[1:4]  # 'yth'
5. Length:
- The len() function can be used to find the length of a string.
s = "Python"
length = len(s)  # 6
6. Membership Testing:
- The in operator is used for membership testing, checking if a substring is present in the string.
s = "Hello World"
is_present = "World" in s  # True
7. Formatting:
- String formatting can be done using the % operator for old-style formatting or using the format() method for newer-style formatting.
name = "Alice"
age = 30
formatted_string = "Name: %s, Age: %d" % (name, age)
or
name = "Alice"
age = 30
formatted_string = "Name: {}, Age: {}".format(name, age)
or using f-strings (available from Python 3.6):
name = "Alice"
age = 30
formatted_string = f"Name: {name}, Age: {age}"
These operations showcase the ways we can work with strings in Python, taking advantage of their immutability and the various methods and operators provided by the language.

# %%
Q3. In 3.X, how do you put non-ASCII Unicode characters in a string?

# %%
#Solution:
In Python 3.x, we can include non-ASCII Unicode characters in a string using Unicode escape sequences or by directly including the Unicode characters.
1. Unicode Escape Sequences:
- We can use escape sequences to represent Unicode characters in a string. The escape sequence starts with \u followed by the Unicode code point in hexadecimal.
# Using Unicode escape sequence
string_with_unicode = "Hello \u03A9"  # Omega symbol (Ω)
In this example, \u03A9 represents the Unicode character U+03A9, which is the Greek capital letter Omega.
2. Direct Inclusion:
- We can directly include Unicode characters in the string if our source code file supports the UTF-8 encoding (which is the default encoding in Python 3).
# Direct inclusion of Unicode character
string_with_unicode = "Hello Ω"  # Omega symbol (Ω)
- Ensure that our source code file is saved in UTF-8 encoding to handle non-ASCII characters correctly.
3. Using Escape Sequences for Special Characters:
- Apart from \u for Unicode characters, we can also use escape sequences for other special characters. For example, \n for a newline, \t for a tab, etc.
# Using escape sequences for special characters
special_chars = "Newline:\nTab:\t"
- Python also supports a wider range of escape sequences, such as \x for hexadecimal escape, and \U for a 32-bit Unicode escape.
# Using \x for hexadecimal escape
hex_escape = "Hexadecimal: \x41"  # 'A'
# Using \U for 32-bit Unicode escape
unicode_32bit = "\U0001F602"  # 😀 (Grinning Face emoji)

# %%
Q4. In Python 3.X, what are the key differences between text-mode and binary-mode files?

# %%
#Solution:
In Python 3.x, when working with files, there are two modes of operation: text mode and binary mode. The key differences between these modes are related to how data is handled and processed.
1. Text Mode:
- Default Mode: When we open a file in text mode (the default mode), Python assumes that we are working with a text file. Text mode is specified by adding 't' or not specifying a mode at all.
- Character Encoding: In text mode, Python automatically handles character encoding and decoding. It uses the default system encoding or the one specified in the locale.getpreferredencoding() function.
- Line Endings: Text mode also handles newline characters ('\n') in a platform-independent way. When reading, it converts platform-specific line endings ('\r\n' on Windows, '\n' on Unix-like systems) to '\n'. When writing, it converts '\n' to the platform-specific line ending.

Example:

# Text mode (default)
with open('text_file.txt', 'rt') as file:
    content = file.read()

2. Binary Mode:
To work with non-text files, such as images or executable files, we can use binary mode. Binary mode is specified by adding 'b' to the mode.
- No Encoding/Decoding: In binary mode, no automatic encoding or decoding of data occurs. It treats the data as a sequence of bytes.
- No Newline Conversion: Binary mode does not perform newline character conversion. It reads and writes data as-is without translating newline characters.
Example:
    
# Binary mode
with open('binary_file.bin', 'rb') as file:
    binary_data = file.read()

3. Universal Newline Mode ('U'):
In Python 3, there's also a universal newline mode ('U'). It works similarly to text mode, but it allows reading and writing files with different newline conventions.
Example:

# Universal newline mode
with open('file.txt', 'rU') as file:
    content = file.read()
In summary, the key differences between text mode and binary mode are related to how data is treated, encoding and decoding, and handling of newline characters. Text mode is suitable for working with text files, while binary mode is used for non-text files where the raw byte data needs to be preserved.

# %%
Q5. How can you interpret a Unicode text file containing text encoded in a different encoding than
your platform's default?

# %%
#Solution:
If we have a Unicode text file that is encoded in a different encoding than our platform's default, we can use the open() function in Python with the encoding parameter to specify the desired encoding for reading the file. This allows us to correctly interpret and handle the text data. Here's an example:

# Specify the encoding when opening the file
file_path = 'unicode_file.txt'
desired_encoding = 'utf-8'  # Replace with the actual encoding of the file

try:
    with open(file_path, 'r', encoding=desired_encoding) as file:
        content = file.read()
        # Process the content as needed
        print(content)
except UnicodeDecodeError as e:
    print(f"Error decoding the file: {e}")

In the example above:
Replace 'utf-8' with the actual encoding of our Unicode text file. Common encodings include UTF-8, UTF-16, ISO-8859-1, etc. If we're unsure about the encoding, we might need to check with the source of the file or try different encodings.
The encoding parameter is crucial when opening the file. It tells Python how to interpret the bytes in the file and convert them into Unicode characters.
If the specified encoding doesn't match the actual encoding of the file, a UnicodeDecodeError may occur. In such cases, we may need to try different encodings or obtain the correct encoding information from the source of the file.
Additionally, we can use the chardet library to automatically detect the encoding of a file. Here's an example:

import chardet

file_path = 'unicode_file.txt'

with open(file_path, 'rb') as file:
    raw_data = file.read()

result = chardet.detect(raw_data)
detected_encoding = result['encoding']

try:
    with open(file_path, 'r', encoding=detected_encoding) as file:
        content = file.read()
        # Process the content as needed
        print(content)
except UnicodeDecodeError as e:
    print(f"Error decoding the file: {e}")
The chardet library analyzes the raw bytes of the file and attempts to detect the encoding. Note that auto-detection is not always perfect, and manual verification may still be necessary.

# %%
Q6. What is the best way to make a Unicode text file in a particular encoding format?

# %%
#Solution:
To create a Unicode text file in a specific encoding format in Python, we can use the open() function with the encoding parameter when writing to the file. Here's an example of how to do this:

# Specify the encoding when creating the file
file_path = 'output_file.txt'
desired_encoding = 'utf-8'  # Replace with the desired encoding

content_to_write = "Hello, 你好, مرحبا"

try:
    with open(file_path, 'w', encoding=desired_encoding) as file:
        file.write(content_to_write)
except UnicodeEncodeError as e:
    print(f"Error encoding the content: {e}")

In this example:
Replace 'utf-8' with the desired encoding for our file. Common encodings include UTF-8, UTF-16, ISO-8859-1, etc. Choose an encoding that is suitable for our use case.
The encoding parameter is crucial when creating the file. It tells Python to encode the Unicode content using the specified encoding before writing it to the file.
If we're working with non-ASCII characters, make sure to include them in the content_to_write. The example includes characters from different scripts: Latin, Chinese, and Arabic.
If we encounter a UnicodeEncodeError, it may be due to characters in the content that cannot be encoded with the specified encoding. In such cases, consider using a different encoding or adjusting the content.
If we want to automatically detect the appropriate encoding for the file, we can use the chardet library. Here's an example:

import chardet

file_path = 'output_file.txt'
content_to_write = "Hello, 你好, مرحبا"

# Detect the encoding of the content
result = chardet.detect(content_to_write.encode())
detected_encoding = result['encoding']

# Write the content to the file with the detected encoding
try:
    with open(file_path, 'w', encoding=detected_encoding) as file:
        file.write(content_to_write)
except UnicodeEncodeError as e:
    print(f"Error encoding the content: {e}")
Keep in mind that automatic encoding detection is not foolproof, and we may need to manually verify or specify the encoding based on the specific requirements of our application or data.

# %%
Q7. What qualifies ASCII text as a form of Unicode text?

# %%
#Solution:
ASCII (American Standard Code for Information Interchange) is a character encoding standard that uses a 7-bit code to represent a set of 128 characters. It includes the basic Latin alphabet, numerals 0-9, various punctuation marks, and control characters. ASCII was originally developed for telecommunication and early computing, and it has been widely used as a character encoding in various applications.
ASCII text is a subset of Unicode text in the sense that the first 128 code points in Unicode are identical to the ASCII characters. In other words, the Unicode code points U+0000 to U+007F directly correspond to the ASCII character set.
Here are some key points regarding ASCII as a subset of Unicode:
1. Compatibility: Unicode was designed to be compatible with ASCII. The first 128 code points in Unicode (U+0000 to U+007F) are reserved for the ASCII characters, and the encoding of these characters in Unicode is the same as in ASCII.
2. Representation: If a piece of text contains only characters within the ASCII range, then that text is inherently a valid Unicode text. Unicode can represent all ASCII characters using the same code points.
3. Interoperability: Unicode provides a way to extend beyond the limitations of ASCII, allowing representation of characters from various writing systems and additional symbols. However, for systems and applications that only need to handle ASCII characters, using Unicode ensures compatibility with the ASCII standard.
In summary, ASCII text is considered a form of Unicode text because the ASCII character set is a subset of Unicode. Unicode extends the capabilities of ASCII by providing a standardized encoding for a much larger set of characters from various scripts and languages. This compatibility allows systems and applications to seamlessly handle both ASCII and extended Unicode characters.

# %%
Q8. How much of an effect does the change in string types in Python 3.X have on your code?

# %%
#Solution:
The change in string types from Python 2 to Python 3 can have a significant impact on code that deals with text processing, especially when it comes to Unicode support. The key differences include:
1. Unicode by Default:
In Python 3, strings are Unicode by default. This means that the basic str type represents Unicode text, and we no longer need to prepend strings with a 'u' to indicate Unicode.

# Python 2
unicode_string = u"This is a Unicode string"

# Python 3
unicode_string = "This is a Unicode string"

2. Bytes and Unicode Separation:
- Python 3 introduces a clear separation between bytes (bytes type) and Unicode text (str type). This separation helps avoid unintentional encoding/decoding issues.

# Python 2
byte_string = "byte data"
unicode_string = u"unicode data"

# Python 3
byte_string = b"byte data"
unicode_string = "unicode data"

3. String Methods and Operations:
Some string methods and operations have changed or been introduced in Python 3. For example, the str methods encode() and decode() are used to convert between Unicode and byte representations.

# Python 2
unicode_string = u"This is a Unicode string"
byte_representation = unicode_string.encode('utf-8')

# Python 3
unicode_string = "This is a Unicode string"
byte_representation = unicode_string.encode('utf-8')

4. Print Statement vs. Print Function:
The print statement in Python 2 has been replaced by the print() function in Python 3. This affects the way you print strings.

# Python 2
print "Hello, World!"

# Python 3
print("Hello, World!")

5. Text File Handling:
When reading from or writing to files, we need to be explicit about the encoding in Python 3. The open() function takes an additional encoding parameter.

# Python 2
with open('file.txt', 'r') as file:
    content = file.read()

# Python 3
with open('file.txt', 'r', encoding='utf-8') as file:
    content = file.read()

6. Comparison and Sorting:
- In Python 3, comparing strings of different types (bytes and Unicode) raises a TypeError. Explicit conversion or careful handling is needed.

# Python 2
result = "abc" < u"def"  # No error

# Python 3
result = b"abc" < "def"  # TypeError: '<' not supported between instances of 'bytes' and 'str'

7. Iterating Over Characters:
In Python 3, iterating over a string gives Unicode characters, whereas in Python 2, it provided bytes.

# Python 2
for char in "abc":
    print char  # Prints individual bytes

# Python 3
for char in "abc":
    print(char)  # Prints Unicode characters

8. Regular Expressions:
Regular expressions in Python 3 operate on Unicode strings by default. In Python 2, we had to use the re.UNICODE flag.

# Python 2
import re
pattern = re.compile(u"pattern", re.UNICODE)

# Python 3
import re
pattern = re.compile("pattern")
